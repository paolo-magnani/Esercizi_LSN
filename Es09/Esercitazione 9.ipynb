# %% [markdown]
# # Esercitazione 9

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import seaborn as sns

x, y = np.loadtxt("best_path.dat", usecols=(1,2), delimiter=',', unpack='true')

plt.plot(x, y, lw=1, marker='o')

plt.show()

# %%
x, y = np.loadtxt("best_path_square.dat", usecols=(1,2), delimiter=',', unpack='true')

plt.plot(x, y, lw=1, marker='o')

plt.show()

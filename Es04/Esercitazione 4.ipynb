# %% [markdown]
# # Esercitazione 4
# Questa è l'esercitazione 4: per prima cosa ho modificato il codice per poter otttenere i dati di output della pressione, poi ho ottimizzato il codice per poter non considerare la brusca diminuzione dei dati termodinamici dovuta alla configurazione iniziale.

# %% [markdown]
# ## Esercizio 4.01

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Esercizio 4.02

# %% [markdown]
# ### Fase solida - Test di equilibrazione

# %%
#RICORDA CHE HAI UNA VARIABILE DI EQUILIBRAZIONE LASCIATA IN BALLO NEL FILE .h
x, pres, error = np.loadtxt("MDNVE_MCNVT/Equil_solid/output_pres.dat", usecols=(0,2,3), unpack='true')
plt.errorbar(x,pres,yerr=error)
plt.xlabel('# blocchi')
plt.ylabel('Pressure [r.u.]')
plt.grid(True)
plt.show()

x, pres, error = np.loadtxt("MDNVE_MCNVT/Equil_solid/output_temp.dat", usecols=(0,2,3), unpack='true')
plt.plot(x,pres)
plt.xlabel('# blocchi')
plt.ylabel('Temperatura [r.u.]')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Fase solida
# Una volta equilibrato, al sistema non interessa più la temperatura di input, dato che la temperatura effettiva del sistema è data dalle velocità delle particelle raggiunta nella prima fase di equilibrazione.

# %%
x, pres, error = np.loadtxt("MDNVE_MCNVT/Solid/output_pres.dat", usecols=(0,2,3), unpack='true')
plt.errorbar(x,pres,yerr=error)
plt.xlabel('# blocchi')
plt.ylabel('Pressure [r.u.]')
plt.grid(True)
plt.show()

# %%
x, pres, error = np.loadtxt("MDNVE_MCNVT/Solid/output_temp.dat", usecols=(0,2,3), unpack='true')
plt.errorbar(x,pres,yerr=error)
plt.xlabel('# blocchi')
plt.ylabel('Temperatura [r.u.]')
plt.grid(True)
plt.show()

# %%
#MI MANCA DA SIMULARE LA FASE LIQUIDA E GASSOSA!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
